# %%
import pandas as pd
df = pd.read_csv(r'circuits.csv', encoding = "latin1")

# %%
df['lat'].mean()
# Out:
# 33.44292506493506

# %%
df['country'].value_counts().idxmax()
# Out:
# 'USA'

# %%
european_countries = ['Germany', 'France', 'UK', ...]

# %%
df[df['country'].isin(european_countries)]['lat'].median()
# Out:
# 49.3292
